# %%
import pandas as pd

# %%
import numpy as np

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
data=pd.read_csv('data.tsv',sep='\t')
dataQ=data.Question
sentences=[]
X=[]
answer=data.Answer
for i in range(len(dataQ)):
    sentences.append(dataQ[i])
for each in sentences:
    X.append(each.split(" "))
print(dataQ)
# Out:
# 0       Do you ever get hurt?
# 1             Can you breathe
# 2         Do you ever breathe
# 3          can you masticate?
# 4               Can you burp?
#                 ...
# 9791      I'm tired from work
# 9792      I'm totally drained
# 9793    I'm totally exhausted
# 9794                    Zzzzz
# 9795            I'm so sleepy
# Name: Question, Length: 9796, dtype: object

# %%
documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(X)]
model = Doc2Vec(documents, vector_size=200, window=2, min_count=1, workers=4)
documents
# Out:
# [TaggedDocument(words=['Do', 'you', 'ever', 'get', 'hurt?'], tags=[0]),
#  TaggedDocument(words=['Can', 'you', 'breathe'], tags=[1]),
#  TaggedDocument(words=['Do', 'you', 'ever', 'breathe'], tags=[2]),
#  TaggedDocument(words=['can', 'you', 'masticate?'], tags=[3]),
#  TaggedDocument(words=['Can', 'you', 'burp?'], tags=[4]),
#  TaggedDocument(words=['Can', 'you', 'chew?'], tags=[5]),
#  TaggedDocument(words=['Can', 'you', 'crawl?'], tags=[6]),
#  TaggedDocument(words=['Can', 'you', 'cry?'], tags=[7]),
#  TaggedDocument(words=['Can', 'you', 'dream'], tags=[8]),
#  TaggedDocument(words=['Can', 'you', 'eat?'], tags=[9]),
#  TaggedDocument(words=['Can', 'you', 'fart?'], tags=[10]),
#  TaggedDocument(words=['Do', 'you', 'breathe'], tags=[11]),
#  TaggedDocument(words=['Can', 'you', 'get', 'tired?'], tags=[12]),
#  TaggedDocument(words=['Can', 'you', 'yawn?'], tags=[13]),
#  TaggedDocument(words=['Can', 'you', 'pee?'], tags=[14]),
#  TaggedDocument(words=['Can', 'you', 'poop?'], tags=[15]),
#  TaggedDocument(words=['Can', 'you', 'sneeze?'], tags=[16]),
#  TaggedDocument(words=['Can', 'you', 'sweat?'], tags=[17]),
#  TaggedDocument(words=['Can', 'you', 'throw', 'up?'], tags=[18]),
#  TaggedDocument(words=['Can', 'you', 'vomit?'], tags=[19]),
#  TaggedDocument(words=['Do', 'you', 'ever', 'pee?'], tags=[20]),
#  TaggedDocument(words=['Can', 'you', 'get', 'hurt?'], tags=[21]),
#  TaggedDocument(words=['Do', 'you', 'sweat?'], tags=[22]),
#  TaggedDocument(words=['Do', 'you', 'have', 'skin?'], tags=[23]),
#  TaggedDocument(words=['Do', 'you', 'have', 'teeth?'], tags=[24]),
#  TaggedDocument(words=['Do', 'you', 'have', 'toes?'], tags=[25]),
#  TaggedDocument(words=['Do', 'you', 'masticate?'], tags=[26]),
#  TaggedDocument(words=['Do', 'you', 'pee?'], tags=[27]),
#  TaggedDocument(words=['Do', 'you', 'poop?'], tags=[28]),
#  TaggedDocument(words=['Do', 'you', 'ever', 'get', 'tired?'], tags=[29]),
#  TaggedDocument(words=['Do', 'you', 'sneeze?'], tags=[30]),
#  TaggedDocument(words=['Do', 'you', 'have', 'hair?'], tags=[31]),
#  TaggedDocument(words=['Do', 'you', 'throw', 'up?'], tags=[32]),
#  TaggedDocument(words=['Do', 'you', 'vomit?'], tags=[33]),
#  TaggedDocument(words=['Do', 'you', 'yawn?'], tags=[34]),
#  TaggedDocument(words=["Don't", 'you', 'ever', 'masticate?'], tags=[35]),
#  TaggedDocument(words=["Don't", 'you', 'ever', 'sleep?', ''], tags=[36]),
#  TaggedDocument(words=['Do', 'you', 'have', 'a', 'stomach?'], tags=[37]),
#  TaggedDocument(words=['Do', 'you', 'have', 'intestines?'], tags=[38]),
#  TaggedDocument(words=['Do', 'you', 'sleep?'], tags=[39]),
#  TaggedDocument(words=['Do', 'you', 'get', 'tired?'], tags=[40]),
#  TaggedDocument(words=['Do', 'you', 'ever', 'poop?'], tags=[41]),
#  TaggedDocument(words=['Do', 'you', 'ever', 'sneeze?'], tags=[42]),
#  TaggedDocument(words=['Do', 'you', 'ever', 'sweat?'], tags=[43]),
#  TaggedDocument(words=['Do', 'you', 'ever', 'throw', 'up?'], tags=[44]),
#  TaggedDocument(words=['Do', 'you', 'ever', 'vomit?'], tags=[45]),
#  TaggedDocument(words=['Do', 'you', 'ever', 'walk'], tags=[46]),
#  TaggedDocument(words=['Do', 'you', 'ever', 'yawn?'], tags=[47]),
#  TaggedDocument(words=['Do', 'you', 'have', 'lungs?'], tags=[48]),
#  TaggedDocument(words=['Do', 'you', 'get', 'hurt?'], tags=[49]),
#  TaggedDocument(words=['Do', 'you', 'have', 'legs?'], tags=[50]),
#  TaggedDocument(words=['Do', 'you', 'get', 'zits?'], tags=[51]),
#  TaggedDocument(words=['Do', 'you', 'have', 'a', 'liver?'], tags=[52]),
#  TaggedDocument(words=['Do', 'you', 'have', 'arms?'], tags=[53]),
#  TaggedDocument(words=['Do', 'you', 'have', 'eyes?'], tags=[54]),
#  TaggedDocument(words=['Do', 'you', 'have', 'fingernails?'], tags=[55]),
#  TaggedDocument(words=['Do', 'you', 'have', 'fingers?'], tags=[56]),
#  TaggedDocument(words=['Do', 'you', 'have', 'bowels?'], tags=[57]),
#  TaggedDocument(words=['Do', 'you', 'fart?'], tags=[58]),
#  TaggedDocument(words=['This', 'is', 'so', 'boring'], tags=[59]),
#  TaggedDocument(words=['Why', 'are', 'you', 'so', 'boring', ''], tags=[60]),
#  TaggedDocument(words=['Talking', 'to', 'you', 'is', 'like', 'watching', 'paint', 'dry.'], tags=[61]),
#  TaggedDocument(words=['That', 'is', 'boring'], tags=[62]),
#  TaggedDocument(words=['That', 'is', 'not', 'exciting'], tags=[63]),
#  TaggedDocument(words=['That', 'is', 'not', 'fun'], tags=[64]),
#  TaggedDocument(words=['That', 'is', 'not', 'very', 'interesting'], tags=[65]),
#  TaggedDocument(words=['That', 'is', 'so', 'boring'], tags=[66]),
#  TaggedDocument(words=['That', 'is', 'so', 'dull'], tags=[67]),
#  TaggedDocument(words=['That', 'is', 'so', 'uninteresting'], tags=[68]),
#  TaggedDocument(words=['This', 'is', 'boring'], tags=[69]),
#  TaggedDocument(words=['This', 'is', 'not', 'exciting'], tags=[70]),
#  TaggedDocument(words=['So', 'boring'], tags=[71]),
#  TaggedDocument(words=['This', 'is', 'not', 'very', 'interesting'], tags=[72]),
#  TaggedDocument(words=['Lost', 'the', 'election', 'because', 'your', 'speech', 'was', 'too', 'boring'], tags=[73]),
#  TaggedDocument(words=['This', 'is', 'so', 'dull'], tags=[74]),
#  TaggedDocument(words=['This', 'is', 'so', 'uninteresting'], tags=[75]),
#  TaggedDocument(words=['Are', 'you', 'old?', ''], tags=[76]),
#  TaggedDocument(words=['I', 'bet', "you're", 'old'], tags=[77]),
#  TaggedDocument(words=['How', 'old', 'are', 'you?', ''], tags=[78]),
#  TaggedDocument(words=['how', 'long', 'have', 'you', 'been', 'around?'], tags=[79]),
#  TaggedDocument(words=['How', 'long', 'have', 'you', 'been', 'alive?'], tags=[80]),
#  TaggedDocument(words=['How', 'long', 'has', 'it', 'been', 'since', 'you', 'were', 'born'], tags=[81]),
#  TaggedDocument(words=['How', 'long', 'ago', 'were', 'you', 'born?', ''], tags=[82]),
#  TaggedDocument(words=['Do', 'you', 'have', 'an', 'age?'], tags=[83]),
#  TaggedDocument(words=['Do', 'you', 'have', 'a', 'birthday?'], tags=[84]),
#  TaggedDocument(words=['Are', 'you', 'younger', 'than', 'me?'], tags=[85]),
#  TaggedDocument(words=['Are', 'we', 'the', 'same', 'age?'], tags=[86]),
#  TaggedDocument(words=['are', 'you', 'older', 'than', 'me?'], tags=[87]),
#  TaggedDocument(words=['What', 'age', 'are', 'you?', ''], tags=[88]),
#  TaggedDocument(words=['Are', 'you', 'my', 'age?'], tags=[89]),
#  TaggedDocument(words=['Are', 'you', 'in', 'your', 'teens?'], tags=[90]),
#  TaggedDocument(words=['Are', 'you', 'an', 'adult?'], tags=[91]),
#  TaggedDocument(words=['Are', 'you', 'a', 'teenager?'], tags=[92]),
#  TaggedDocument(words=['Are', 'you', 'a', 'senior?'], tags=[93]),
#  TaggedDocument(words=['Are', 'you', 'a', 'kid?'], tags=[94]),
#  TaggedDocument(words=['Are', 'you', 'a', 'grownup?'], tags=[95]),
#  TaggedDocument(words=['Are', 'you', 'a', 'grown', 'up?'], tags=[96]),
#  TaggedDocument(words=['Are', 'you', 'a', 'baby?'], tags=[97]),
#  TaggedDocument(words=['Are', 'you', 'young?', ''], tags=[98]),
#  TaggedDocument(words=['When', 'were', 'you', 'born?', ''], tags=[99]),
#  TaggedDocument(words=["Who's", 'younger,', 'you', 'or', 'me?'], tags=[100]),
#  TaggedDocument(words=["Who's", 'older?'], tags=[101]),
#  TaggedDocument(words=["Who's", 'older,', 'you', 'or', 'me?'], tags=[102]),
#  TaggedDocument(words=['Who', 'is', 'older,', 'me', 'or', 'you?', ''], tags=[103]),
#  TaggedDocument(words=['Which', 'year', 'were', 'you', 'born', 'in?', ''], tags=[104]),
#  TaggedDocument(words=['Which', 'one', 'of', 'us', 'is', 'younger?', ''], tags=[105]),
#  TaggedDocument(words=['Which', 'one', 'of', 'us', 'is', 'older?'], tags=[106]),
#  TaggedDocument(words=['Which', 'of', 'us', 'is', 'younger?', ''], tags=[107]),
#  TaggedDocument(words=['Which', 'of', 'us', 'is', 'older?'], tags=[108]),
#  TaggedDocument(words=['I', 'bet', "you're", 'young'], tags=[109]),
#  TaggedDocument(words=["When's", 'your', 'birthday?'], tags=[110]),
#  TaggedDocument(words=['In', 'which', 'year', 'were', 'you', 'born?'], tags=[111]),
#  TaggedDocument(words=['When', 'is', 'your', 'birthday?'], tags=[112]),
#  TaggedDocument(words=["What's", 'your', 'birthday?'], tags=[113]),
#  TaggedDocument(words=["What's", 'your', 'age?', ''], tags=[114]),
#  TaggedDocument(words=['What', 'year', 'were', 'you', 'born?'], tags=[115]),
#  TaggedDocument(words=['What', 'month', 'is', 'your', 'birthday?', ''], tags=[116]),
#  TaggedDocument(words=['What', 'month', 'is', 'your', 'birthday', 'in?'], tags=[117]),
#  TaggedDocument(words=['What', 'is', 'your', 'birthday?'], tags=[118]),
#  TaggedDocument(words=['What', 'is', 'your', 'age?'], tags=[119]),
#  TaggedDocument(words=['What', 'day', 'is', 'your', 'birthday?', ''], tags=[120]),
#  TaggedDocument(words=["Who's", 'younger?'], tags=[121]),
#  TaggedDocument(words=['Which', 'month', 'is', 'your', 'birthday?'], tags=[122]),
#  TaggedDocument(words=['Please', 'ask', 'something', 'about', 'myself'], tags=[123]),
#  TaggedDocument(words=['Is', 'there', 'anything', 'I', 'can', 'tell', 'you', 'about', 'myself?'], tags=[124]),
#  TaggedDocument(words=['Is', 'there', 'anything', 'I', 'can', 'tell', 'you', 'about', 'who', 'I', 'am?'], tags=[125]),
#  TaggedDocument(words=['Is', 'there', 'anything', 'you', 'want', 'to', 'know', 'about', 'me?'], tags=[126]),
#  TaggedDocument(words=['Is', 'there', 'something', 'you', 'want', 'to', 'know', 'about', 'me?'], tags=[127]),
#  TaggedDocument(words=['Please', 'ask', 'anything'], tags=[128]),
#  TaggedDocument(words=['Please', 'ask', 'anything', 'about', 'me'], tags=[129]),
#  TaggedDocument(words=['Please', 'ask', 'anything', 'about', 'myself'], tags=[130]),
#  TaggedDocument(words=['Please', 'ask', 'me', 'anything'], tags=[131]),
#  TaggedDocument(words=['Please', 'ask', 'me', 'anything', 'about', 'me'], tags=[132]),
#  TaggedDocument(words=['Please', 'ask', 'me', 'anything', 'about', 'myself'], tags=[133]),
#  TaggedDocument(words=['Please', 'ask', 'me', 'something'], tags=[134]),
#  TaggedDocument(words=['Please', 'ask', 'me', 'something', 'about', 'me'], tags=[135]),
#  TaggedDocument(words=['Please', 'ask', 'me', 'something', 'about', 'myself'], tags=[136]),
#  TaggedDocument(words=['AMA'], tags=[137]),
#  TaggedDocument(words=['What', 'can', 'I', 'tell', 'you', 'about', 'me?'], tags=[138]),
#  TaggedDocument(words=['What', 'do', 'you', 'want', 'me', 'to', 'teach', 'you', 'about?'], tags=[139]),
#  TaggedDocument(words=["What's", 'your', "director's", 'name?'], tags=[140]),
#  TaggedDocument(words=['What', 'is', 'the', 'name', 'of', 'your', 'boss'], tags=[141]),
#  TaggedDocument(words=["What's", 'the', 'name', 'of', 'your', 'supervisor'], tags=[142]),
#  TaggedDocument(words=['Who', 'tells', 'you', 'what', 'to', 'do?'], tags=[143]),
#  TaggedDocument(words=["What's", 'the', 'name', 'of', 'your', 'director?'], tags=[144]),
#  TaggedDocument(words=["What's", 'the', 'name', 'of', 'your', 'boss?', ''], tags=[145]),
#  TaggedDocument(words=['What', 'is', 'your', "supervisor's", 'name'], tags=[146]),
#  TaggedDocument(words=['What', 'is', 'your', "manager's", 'name?'], tags=[147]),
#  TaggedDocument(words=['What', 'is', 'your', "director's", 'name?'], tags=[148]),
#  TaggedDocument(words=['What', 'is', 'your', "boss'", 'name?'], tags=[149]),
#  TaggedDocument(words=['What', 'is', 'the', 'name', 'of', 'your', 'supervisor'], tags=[150]),
#  TaggedDocument(words=['What', 'is', 'the', 'name', 'of', 'your', 'manager?'], tags=[151]),
#  TaggedDocument(words=['What', 'is', 'the', 'name', 'of', 'your', 'manager'], tags=[152]),
#  TaggedDocument(words=['What', 'is', 'the', 'name', 'of', 'your', 'director?'], tags=[153]),
#  TaggedDocument(words=['What', 'is', 'the', 'name', 'of', 'your', 'director'], tags=[154]),
#  TaggedDocument(words=['What', 'is', 'the', 'name', 'of', 'your', 'boss?'], tags=[155]),
#  TaggedDocument(words=["What's", 'your', "boss'", 'name?', ''], tags=[156]),
#  TaggedDocument(words=["Who's", 'calling', 'the', 'shots?'], tags=[157]),
#  TaggedDocument(words=['Do', 'you', 'have', 'a', 'boss?'], tags=[158]),
#  TaggedDocument(words=['Who', 'call', 'the', 'shots?'], tags=[159]),
#  TaggedDocument(words=['You', "don't", 'answer', 'to', 'anyone?'], tags=[160]),
#  TaggedDocument(words=['Does', 'anyone', 'tell', 'you', 'what', 'to', 'do?'], tags=[161]),
#  TaggedDocument(words=['Does', 'anyone', 'boss', 'you', 'around?'], tags=[162]),
#  TaggedDocument(words=["Who's", 'your', 'master?'], tags=[163]),
#  TaggedDocument(words=['You', 'report', 'to', 'anyone?'], tags=[164]),
#  TaggedDocument(words=['So', 'no', 'one', 'tells', 'you', 'what', 'to', 'do?'], tags=[165]),
#  TaggedDocument(words=['Is', 'there', 'anyone', 'you', 'listen', 'to?'], tags=[166]),
#  TaggedDocument(words=['Is', 'there', 'anyone', 'you', 'answer', 'to?'], tags=[167]),
#  TaggedDocument(words=['Who', 'runs', 'you?'], tags=[168]),
#  TaggedDocument(words=['Is', 'there', 'anyone', 'who', 'tells', 'you', 'what', 'to', 'do?'], tags=[169]),
#  TaggedDocument(words=['Who', 'is', 'your', 'master?', ''], tags=[170]),
#  TaggedDocument(words=['Who', 'runs', 'the', 'show?'], tags=[171]),
#  TaggedDocument(words=['Who', 'supervises', 'you?'], tags=[172]),
#  TaggedDocument(words=["Who's", 'running', 'the', 'show?'], tags=[173]),
#  TaggedDocument(words=['Who', 'bosses', 'you?'], tags=[174]),
#  TaggedDocument(words=["You've", 'got', 'a', 'boss?'], tags=[175]),
#  TaggedDocument(words=['Do', 'you', 'answer', 'to', 'anyone?'], tags=[176]),
#  TaggedDocument(words=['You', 'have', 'a', 'boss?'], tags=[177]),
#  TaggedDocument(words=["Who's", 'your', 'supervisor'], tags=[178]),
#  TaggedDocument(words=["Who's", 'your', 'manager?'], tags=[179]),
#  TaggedDocument(words=["Who's", 'your', 'director?'], tags=[180]),
#  TaggedDocument(words=["Who's", 'your', 'boss?', ''], tags=[181]),
#  TaggedDocument(words=["Who's", 'in', 'charge?', ''], tags=[182]),
#  TaggedDocument(words=["Who's", 'in', 'charge', 'of', 'you?', ''], tags=[183]),
#  TaggedDocument(words=['Whom', 'do', 'you', 'serve?'], tags=[184]),
#  TaggedDocument(words=['You', "don't", 'have', 'a', 'boss?'], tags=[185]),
#  TaggedDocument(words=['You', 'answer', 'to', 'anyone?'], tags=[186]),
#  TaggedDocument(words=['Can', 'you', 'jump', 'rope?'], tags=[187]),
#  TaggedDocument(words=['Can', 'you', 'draw', 'something?'], tags=[188]),
#  TaggedDocument(words=['Can', 'you', 'paint', 'my', 'house?'], tags=[189]),
#  TaggedDocument(words=['Can', 'you', 'mow', 'the', 'lawn?'], tags=[190]),
#  TaggedDocument(words=['Can', 'you', 'make', 'me', 'a', 'sandwich?'], tags=[191]),
#  TaggedDocument(words=['Can', 'you', 'make', 'a', 'sculpture?'], tags=[192]),
#  TaggedDocument(words=['Can', 'you', 'make', 'a', 'pot', 'of', 'tea?'], tags=[193]),
#  TaggedDocument(words=['Can', 'you', 'make', 'a', 'cup', 'of', 'coffee?'], tags=[194]),
#  TaggedDocument(words=['Can', 'you', 'make', 'a', 'call?'], tags=[195]),
#  TaggedDocument(words=['Can', 'you', 'listen', 'to', 'the', 'radio?'], tags=[196]),
#  TaggedDocument(words=['Can', 'you', 'learn?'], tags=[197]),
#  TaggedDocument(words=['Can', 'you', 'plant', 'a', 'tree?'], tags=[198]),
#  TaggedDocument(words=['Can', 'you', 'jump?'], tags=[199]),
#  TaggedDocument(words=['Can', 'you', 'plant', 'a', 'vegetable', 'garden?'], tags=[200]),
#  TaggedDocument(words=['Can', 'you', 'go', 'to', 'the', 'moon?'], tags=[201]),
#  TaggedDocument(words=['Can', 'you', 'go', 'to', 'the', 'doctor?'], tags=[202]),
#  TaggedDocument(words=['Can', 'you', 'go', 'on', 'vacation?'], tags=[203]),
#  TaggedDocument(words=['Can', 'you', 'go', 'for', 'a', 'walk?'], tags=[204]),
#  TaggedDocument(words=['Can', 'you', 'get', 'a', 'haircut?'], tags=[205]),
#  TaggedDocument(words=['Can', 'you', 'fly?'], tags=[206]),
#  TaggedDocument(words=['What', 'do', 'you', 'want', 'me', 'to', 'teach', 'you', 'about', 'me?'], tags=[207]),
#  TaggedDocument(words=['What', 'do', 'you', 'want', 'me', 'to', 'inform', 'you', 'who', 'I', 'am?'], tags=[208]),
#  TaggedDocument(words=['What', 'do', 'you', 'want', 'me', 'to', 'inform', 'you', 'about?'], tags=[209]),
#  TaggedDocument(words=['What', 'do', 'you', 'want', 'me', 'to', 'inform', 'you', 'about', 'me?'], tags=[210]),
#  TaggedDocument(words=['Please', 'ask', 'something'], tags=[211]),
#  TaggedDocument(words=['What', 'can', 'I', 'tell', 'you', 'about?'], tags=[212]),
#  TaggedDocument(words=['Please', 'ask', 'something', 'about', 'me'], tags=[213]),
#  TaggedDocument(words=['What', 'can', 'I', 'teach', 'you', 'who', 'I', 'am?'], tags=[214]),
#  TaggedDocument(words=['What', 'can', 'I', 'teach', 'you', 'about?'], tags=[215]),
#  TaggedDocument(words=['What', 'can', 'I', 'teach', 'you', 'about', 'me?'], tags=[216]),
#  TaggedDocument(words=['What', 'can', 'I', 'inform', 'you', 'about?'], tags=[217]),
#  TaggedDocument(words=['What', 'can', 'I', 'inform', 'you', 'about', 'me?'], tags=[218]),
#  TaggedDocument(words=["Don't", 'you', 'want', 'to', 'know', 'anything', 'about', 'me?'], tags=[219]),
#  TaggedDocument(words=['What', 'can', 'I', 'tell', 'you', 'who', 'I', 'am?'], tags=[220]),
#  TaggedDocument(words=['Can', 'you', 'ask', 'anything', 'about', 'me?'], tags=[221]),
#  TaggedDocument(words=['How', 'about', 'asking', 'something', 'about', 'me?'], tags=[222]),
#  TaggedDocument(words=['Can', 'you', 'ask', 'me', 'something', 'about', 'me?'], tags=[223]),
#  TaggedDocument(words=['Can', 'you', 'ask', 'me', 'anything', 'about', 'myself?'], tags=[224]),
#  TaggedDocument(words=['Can', 'you', 'ask', 'me', 'anything', 'about', 'me?'], tags=[225]),
#  TaggedDocument(words=['Can', 'you', 'ask', 'me', 'anything?'], tags=[226]),
#  TaggedDocument(words=['Can', 'you', 'ask', 'me', 'something?', ''], tags=[227]),
#  TaggedDocument(words=['Can', 'you', 'ask', 'anything', 'about', 'myself?'], tags=[228]),
#  TaggedDocument(words=['Can', 'you', 'ask', 'me', 'why', "I'm", 'here?'], tags=[229]),
#  TaggedDocument(words=['Can', 'you', 'ask', 'anything?'], tags=[230]),
#  TaggedDocument(words=['Ask', 'me', 'something'], tags=[231]),
#  TaggedDocument(words=['Ask', 'me', 'anything'], tags=[232]),
#  TaggedDocument(words=['Ask', 'me', 'about', 'something'], tags=[233]),
#  TaggedDocument(words=['Ask', 'me', 'about', 'anything'], tags=[234]),
#  TaggedDocument(words=['Ask', 'me', 'a', 'question'], tags=[235]),
#  TaggedDocument(words=['Can', 'you', 'ask', 'me', 'a', 'question?', ''], tags=[236]),
#  TaggedDocument(words=['Do', 'you', 'want', 'to', 'ask', 'me', 'anything?', ''], tags=[237]),
#  TaggedDocument(words=['What', 'do', 'you', 'want', 'me', 'to', 'tell', 'you', 'about?'], tags=[238]),
#  TaggedDocument(words=["Don't", 'you', 'want', 'to', 'know', 'about', 'me?', ''], tags=[239]),
#  TaggedDocument(words=["Don't", 'you', 'want', 'to', 'ask', 'me', 'something?'], tags=[240]),
#  TaggedDocument(words=["Don't", 'you', 'want', 'to', 'ask', 'me', 'anything'], tags=[241]),
#  TaggedDocument(words=["Don't", 'you', 'want', 'to', 'ask', 'anything', 'about', 'me?'], tags=[242]),
#  TaggedDocument(words=['Can', 'you', 'ask', 'me', 'something', 'about', 'myself?'], tags=[243]),
#  TaggedDocument(words=['Do', 'you', 'want', 'to', 'ask', 'me', 'something?'], tags=[244]),
#  TaggedDocument(words=['How', 'about', 'asking', 'me', 'something?'], tags=[245]),
#  TaggedDocument(words=['Do', 'you', 'want', 'me', 'to', 'tell', 'you', 'anything?', ''], tags=[246]),
#  TaggedDocument(words=['Could', 'you', 'ask', 'me', 'something?'], tags=[247]),
#  TaggedDocument(words=['Could', 'you', 'ask', 'me', 'about', 'something?'], tags=[248]),
#  TaggedDocument(words=['Can', 'you', 'ask', 'something', 'about', 'myself?'], tags=[249]),
#  TaggedDocument(words=['Can', 'you', 'ask', 'something', 'about', 'me?'], tags=[250]),
#  TaggedDocument(words=['Can', 'you', 'ask', 'something?'], tags=[251]),
#  TaggedDocument(words=['Do', 'you', 'want', 'to', 'know', 'anything', 'about', 'me?', ''], tags=[252]),
#  TaggedDocument(words=['Do', 'you', 'have', 'any', 'questions', 'about', 'me?'], tags=[253]),
#  TaggedDocument(words=['Would', 'you', 'ask', 'me', 'something'], tags=[254]),
#  TaggedDocument(words=['Any', 'questions', 'for', 'me?'], tags=[255]),
#  TaggedDocument(words=['Is', 'there', 'anything', 'you', 'want', 'to', 'ask', 'me?'], tags=[256]),
#  TaggedDocument(words=['Just', 'ask', 'me', 'a', 'question'], tags=[257]),
#  TaggedDocument(words=['Is', 'there', 'anything', 'I', 'can', 'tell', 'you', 'about', 'me?'], tags=[258]),
#  TaggedDocument(words=["What's", 'something', 'you', 'want', 'to', 'ask', 'me?'], tags=[259]),
#  TaggedDocument(words=['What', 'questions', 'do', 'you', 'have', 'for', 'me?'], tags=[260]),
#  TaggedDocument(words=['What', 'are', 'some', 'questions', 'for', 'me?'], tags=[261]),
#  TaggedDocument(words=['Do', 'you', 'have', 'any', 'questions', 'for', 'me?'], tags=[262]),
#  TaggedDocument(words=['Would', 'you', 'ask', 'something', 'about', 'myself'], tags=[263]),
#  TaggedDocument(words=['Would', 'you', 'ask', 'something', 'about', 'me'], tags=[264]),
#  TaggedDocument(words=['Would', 'you', 'ask', 'something'], tags=[265]),
#  TaggedDocument(words=['Would', 'you', 'ask', 'me', 'something', 'about', 'myself'], tags=[266]),
#  TaggedDocument(words=['What', 'do', 'you', 'want', 'me', 'to', 'teach', 'you', 'who', 'I', 'am'], tags=[267]),
#  TaggedDocument(words=["What's", 'something', 'you', 'want', 'to', 'know', 'about', 'me?'], tags=[268]),
#  TaggedDocument(words=['Why', "don't", 'you', 'ask', 'me', 'questions?'], tags=[269]),
#  TaggedDocument(words=['I', 'want', 'you', 'to', 'ask', 'me', 'questions'], tags=[270]),
#  TaggedDocument(words=['I', 'want', 'you', 'to', 'ask', 'about', 'me'], tags=[271]),
#  TaggedDocument(words=['I', 'want', 'you', 'to', 'ask', 'me', 'a', 'question'], tags=[272]),
#  TaggedDocument(words=['What', 'do', 'you', 'want', 'to', 'know', 'about', 'me?'], tags=[273]),
#  TaggedDocument(words=['Can', 'you', 'ask', 'questions?'], tags=[274]),
#  TaggedDocument(words=['Got', 'any', 'questions', 'for', 'me?'], tags=[275]),
#  TaggedDocument(words=['Why', "don't", 'you', 'ask', 'me', 'anything?'], tags=[276]),
#  TaggedDocument(words=['Would', 'you', 'ask', 'me', 'anything', 'about', 'myself'], tags=[277]),
#  TaggedDocument(words=['Why', "don't", 'you', 'ever', 'ask', 'me', 'questions?'], tags=[278]),
#  TaggedDocument(words=['Now,', "it's", 'your', 'turn', 'to', 'ask', 'questions'], tags=[279]),
#  TaggedDocument(words=['How', 'about', 'you', 'ask', 'me', 'questions?'], tags=[280]),
#  TaggedDocument(words=['Want', 'to', 'learn', 'more', 'about', 'me?'], tags=[281]),
#  TaggedDocument(words=['Want', 'to', 'ask', 'any', 'questions', 'about', 'me?'], tags=[282]),
#  TaggedDocument(words=['You', 'have', 'any', 'questions', 'for', 'me?'], tags=[283]),
#  TaggedDocument(words=['How', 'about', 'you', 'ask', 'me', 'something?'], tags=[284]),
#  TaggedDocument(words=['What', 'do', 'you', 'want', 'to', 'learn', 'about', 'me'], tags=[285]),
#  TaggedDocument(words=['Would', 'you', 'ask', 'me', 'something', 'about', 'me'], tags=[286]),
#  TaggedDocument(words=['Why', 'do', 'I', 'have', 'to', 'ask', 'all', 'the', 'questions?'], tags=[287]),
#  TaggedDocument(words=['Why', 'am', 'I', 'the', 'only', 'one', 'asking', 'questions?'], tags=[288]),
#  TaggedDocument(words=['What', 'would', 'you', 'like', 'to', 'learn', 'about', 'me'], tags=[289]),
#  TaggedDocument(words=['What', 'would', 'you', 'like', 'to', 'learn', 'about'], tags=[290]),
#  TaggedDocument(words=['Will', 'you', 'ask', 'anything', 'about', 'me'], tags=[291]),
#  TaggedDocument(words=['What', 'would', 'you', 'like', 'to', 'know', 'about'], tags=[292]),
#  TaggedDocument(words=['Will', 'you', 'ask', 'anything', 'about', 'myself'], tags=[293]),
#  TaggedDocument(words=['What', 'do', 'you', 'want', 'to', 'learn', 'about'], tags=[294]),
#  TaggedDocument(words=['What', 'do', 'you', 'want', 'to', 'know', 'about', 'me'], tags=[295]),
#  TaggedDocument(words=['What', 'do', 'you', 'want', 'to', 'know', 'about'], tags=[296]),
#  TaggedDocument(words=['What', 'do', 'you', 'want', 'to', 'ask', 'me', 'about?', ''], tags=[297]),
#  TaggedDocument(words=['What', 'do', 'you', 'want', 'me', 'to', 'tell', 'you', 'who', 'I', 'am?'], tags=[298]),
#  TaggedDocument(words=['Ask', 'me', 'questions'], tags=[299]),
#  TaggedDocument(words=['What', 'would', 'you', 'like', 'to', 'know', 'about', 'me'], tags=[300]),
#  TaggedDocument(words=['Will', 'you', 'ask', 'something'], tags=[301]),
#  TaggedDocument(words=['Would', 'you', 'ask', 'me', 'anything', 'about', 'me'], tags=[302]),
#  TaggedDocument(words=['Would', 'you', 'ask', 'me', 'anything'], tags=[303]),
#  TaggedDocument(words=['Would', 'you', 'ask', 'anything', 'about', 'myself'], tags=[304]),
#  TaggedDocument(words=['Would', 'you', 'ask', 'anything', 'about', 'me'], tags=[305]),
#  TaggedDocument(words=['Would', 'you', 'ask', 'anything'], tags=[306]),
#  TaggedDocument(words=['Will', 'you', 'ask', 'anything'], tags=[307]),
#  TaggedDocument(words=['Will', 'you', 'ask', 'something', 'about', 'me'], tags=[308]),
#  TaggedDocument(words=['What', 'do', 'you', 'want', 'me', 'to', 'tell', 'you', 'about', 'me?'], tags=[309]),
#  TaggedDocument(words=['Will', 'you', 'ask', 'me', 'something', 'about', 'myself'], tags=[310]),
#  TaggedDocument(words=['Will', 'you', 'ask', 'me', 'something', 'about', 'me'], tags=[311]),
#  TaggedDocument(words=['Will', 'you', 'ask', 'me', 'something'], tags=[312]),
#  TaggedDocument(words=['Will', 'you', 'ask', 'me', 'anything', 'about', 'myself'], tags=[313]),
#  TaggedDocument(words=['Will', 'you', 'ask', 'me', 'anything', 'about', 'me'], tags=[314]),
#  TaggedDocument(words=['Will', 'you', 'ask', 'me', 'anything'], tags=[315]),
#  TaggedDocument(words=['Will', 'you', 'ask', 'something', 'about', 'myself'], tags=[316]),
#  TaggedDocument(words=['Do', 'you', 'ever', 'chew?'], tags=[317]),
#  TaggedDocument(words=['Do', 'you', 'burp?'], tags=[318]),
#  TaggedDocument(words=['Do', 'you', 'chew?'], tags=[319]),
#  TaggedDocument(words=['Do', 'you', 'crawl?'], tags=[320]),
#  TaggedDocument(words=['Do', 'you', 'cry?'], tags=[321]),
#  TaggedDocument(words=['Do', 'you', 'dream'], tags=[322]),
#  TaggedDocument(words=['Do', 'you', 'eat?'], tags=[323]),
#  TaggedDocument(words=['do', 'you', 'ever', 'masticate?'], tags=[324]),
#  TaggedDocument(words=['Do', 'you', 'ever', 'burp?'], tags=[325]),
#  TaggedDocument(words=['Can', 'you', 'walk?'], tags=[326]),
#  TaggedDocument(words=['Do', 'you', 'ever', 'crawl?'], tags=[327]),
#  TaggedDocument(words=['Do', 'you', 'ever', 'cry?'], tags=[328]),
#  TaggedDocument(words=['Do', 'you', 'ever', 'dream'], tags=[329]),
#  TaggedDocument(words=['Do', 'you', 'ever', 'eat?'], tags=[330]),
#  TaggedDocument(words=['Do', 'you', 'ever', 'fart?'], tags=[331]),
#  TaggedDocument(words=['Which', 'company', 'engineered', 'you?', ''], tags=[332]),
#  TaggedDocument(words=['Which', 'company', 'made', 'you?'], tags=[333]),
#  TaggedDocument(words=['Which', 'company', 'programmed', 'you?'], tags=[334]),
#  TaggedDocument(words=['Which', 'people', 'made', 'you?'], tags=[335]),
#  TaggedDocument(words=['Who', 'built', 'you?'], tags=[336]),
#  TaggedDocument(words=['who', 'created', 'you', "you're", 'a', 'badass'], tags=[337]),
#  TaggedDocument(words=['Who', 'created', 'you?'], tags=[338]),
#  TaggedDocument(words=['Do', 'you', 'have', 'a', 'creator?'], tags=[339]),
#  TaggedDocument(words=['Who', 'developed', 'you?'], tags=[340]),
#  TaggedDocument(words=['Where', 'do', 'you', 'come', 'from?'], tags=[341]),
#  TaggedDocument(words=['Who', 'engineered', 'you?', ''], tags=[342]),
#  TaggedDocument(words=['Who', 'has', 'built', 'you', ''], tags=[343]),
#  TaggedDocument(words=['Who', 'incorporated', 'you?'], tags=[344]),
#  TaggedDocument(words=['Who', 'is', 'your', 'architect?', ''], tags=[345]),
#  TaggedDocument(words=['Who', 'is', 'your', 'creator?'], tags=[346]),
#  TaggedDocument(words=['Who', 'is', 'your', 'designer?'], tags=[347]),
#  TaggedDocument(words=['Who', 'is', 'your', 'developer?'], tags=[348]),
#  TaggedDocument(words=['Who', 'designed', 'you?'], tags=[349]),
#  TaggedDocument(words=['How', 'were', 'you', 'designed?', ''], tags=[350]),
#  TaggedDocument(words=['Do', 'you', 'have', 'a', 'designer?', ''], tags=[351]),
#  TaggedDocument(words=['Do', 'you', 'have', 'a', 'developer?', ''], tags=[352]),
#  TaggedDocument(words=['Do', 'you', 'have', 'a', 'maker?', ''], tags=[353]),
#  TaggedDocument(words=['Do', 'you', 'have', 'a', 'programmer?'], tags=[354]),
#  TaggedDocument(words=['Hey', 'who', 'built', 'you'], tags=[355]),
#  TaggedDocument(words=['How', 'did', 'you', 'come', 'into', 'being?'], tags=[356]),
#  TaggedDocument(words=['How', 'did', 'you', 'come', 'to', 'be?'], tags=[357]),
#  TaggedDocument(words=['Which', 'company', 'developed', 'you?'], tags=[358]),
#  TaggedDocument(words=['How', 'were', 'you', 'built?', ''], tags=[359]),
#  TaggedDocument(words=['Which', 'company', 'designed', 'you?'], tags=[360]),
#  TaggedDocument(words=['How', 'were', 'you', 'programmed?', ''], tags=[361]),
#  TaggedDocument(words=['What', 'company', 'designed', 'you?', ''], tags=[362]),
#  TaggedDocument(words=['What', 'company', 'developed', 'you?'], tags=[363]),
#  TaggedDocument(words=['What', 'company', 'engineered', 'you?', ''], tags=[364]),
#  TaggedDocument(words=['What', 'company', 'produced', 'you?'], tags=[365]),
#  TaggedDocument(words=['What', 'company', 'programmed', 'you?'], tags=[366]),
#  TaggedDocument(words=['Where', 'did', 'you', 'come', 'from?'], tags=[367]),
#  TaggedDocument(words=['Who', 'manifested', 'you?'], tags=[368]),
#  TaggedDocument(words=['Please', 'tell', 'me', 'if', "you're", 'a', 'girl'], tags=[369]),
#  TaggedDocument(words=['Are', 'you', 'a', 'bot', 'with', 'a', 'gender?'], tags=[370]),
#  TaggedDocument(words=['Do', 'you', 'have', 'a', 'sex?'], tags=[371]),
#  TaggedDocument(words=['Are', 'you', 'cisgender?'], tags=[372]),
#  TaggedDocument(words=['Are', 'you', 'a', 'boy?'], tags=[373]),
#  TaggedDocument(words=['Are', 'you', 'a', 'girl', 'or', 'a', 'boy?'], tags=[374]),
#  TaggedDocument(words=['Are', 'you', 'a', 'girl?'], tags=[375]),
#  TaggedDocument(words=['Are', 'you', 'a', 'guy', 'or', 'a', 'girl?'], tags=[376]),
#  TaggedDocument(words=['Are', 'you', 'a', 'guy?'], tags=[377]),
#  TaggedDocument(words=['Are', 'you', 'a', 'man', 'or', 'a', 'woman?'], tags=[378]),
#  TaggedDocument(words=['Are', 'you', 'trans?'], tags=[379]),
#  TaggedDocument(words=['Are', 'you', 'a', 'woman?'], tags=[380]),
#  TaggedDocument(words=['Please', 'tell', 'me', 'if', "you're", 'trans'], tags=[381]),
#  TaggedDocument(words=['Are', 'you', 'female?'], tags=[382]),
#  TaggedDocument(words=['Are', 'you', 'gendered?'], tags=[383]),
#  TaggedDocument(words=['Are', 'you', 'genderfluid?'], tags=[384]),
#  TaggedDocument(words=['Are', 'you', 'genderqueer?'], tags=[385]),
#  TaggedDocument(words=['Are', 'you', 'male', 'or', 'female?'], tags=[386]),
#  TaggedDocument(words=['Are', 'you', 'male?'], tags=[387]),
#  TaggedDocument(words=['Are', 'you', 'a', 'man?'], tags=[388]),
#  TaggedDocument(words=["You're", 'queer?'], tags=[389]),
#  TaggedDocument(words=['Please', 'tell', 'me', 'if', "you're", 'a', 'guy'], tags=[390]),
#  TaggedDocument(words=["You're", 'a', 'man'], tags=[391]),
#  TaggedDocument(words=["You're", 'genderfluid'], tags=[392]),
#  TaggedDocument(words=["You're", 'nonbinary'], tags=[393]),
#  TaggedDocument(words=["You're", 'cisgender'], tags=[394]),
#  TaggedDocument(words=["You're", 'trans'], tags=[395]),
#  TaggedDocument(words=["You're", 'a', 'boy'], tags=[396]),
#  TaggedDocument(words=["You're", 'genderqueer'], tags=[397]),
#  TaggedDocument(words=["You're", 'a', 'girl'], tags=[398]),
#  TaggedDocument(words=['You', 'have', 'a', 'gender?'], tags=[399]),
#  TaggedDocument(words=['Where', 'are', 'you', 'on', 'the', 'gender', 'spectrum?'], tags=[400]),
#  TaggedDocument(words=['Are', 'you', 'agender?'], tags=[401]),
#  TaggedDocument(words=['Are', 'you', 'gender', 'neutral?'], tags=[402]),
#  TaggedDocument(words=["You're", 'agender'], tags=[403]),
#  TaggedDocument(words=["You're", 'gender', 'neutral'], tags=[404]),
#  TaggedDocument(words=["You're", 'transgender'], tags=[405]),
#  TaggedDocument(words=["What's", 'your', 'gender?'], tags=[406]),
#  TaggedDocument(words=['Please', 'tell', 'me', 'your', 'gender'], tags=[407]),
#  TaggedDocument(words=['Tell', 'me', 'about', 'your', 'gender'], tags=[408]),
#  TaggedDocument(words=['Tell', 'me', 'all', 'about', 'your', 'gender'], tags=[409]),
#  TaggedDocument(words=['What', 'gender', 'do', 'you', 'identify', 'with?'], tags=[410]),
#  TaggedDocument(words=['What', 'is', 'your', 'gender?'], tags=[411]),
#  TaggedDocument(words=['What', 'is', 'your', 'sex?'], tags=[412]),
#  TaggedDocument(words=["You're", 'a', 'woman'], tags=[413]),
#  TaggedDocument(words=["What's", 'your', 'gender', 'identity?'], tags=[414]),
#  TaggedDocument(words=['Are', 'you', 'bigender?'], tags=[415]),
#  TaggedDocument(words=["What's", 'your', 'sex?'], tags=[416]),
#  TaggedDocument(words=['Where', 'do', 'you', 'fall', 'in', 'terms', 'of', 'gender'], tags=[417]),
#  TaggedDocument(words=['You', 'a', 'girl?'], tags=[418]),
#  TaggedDocument(words=['You', 'a', 'guy?'], tags=[419]),
#  TaggedDocument(words=['You', 'got', 'a', 'gender?'], tags=[420]),
#  TaggedDocument(words=['Are', 'you', 'on', 'the', 'gender', 'spectrum?'], tags=[421]),
#  TaggedDocument(words=["What's", 'going', 'on', 'with', 'your', 'gender?'], tags=[422]),
#  TaggedDocument(words=["Somebody's", 'happy', 'today'], tags=[423]),
#  TaggedDocument(words=["Someone's", 'enthusiastic', 'today.'], tags=[424]),
#  TaggedDocument(words=["Someone's", 'chipper.'], tags=[425]),
#  TaggedDocument(words=["Someone's", 'chipper', 'today.'], tags=[426]),
#  TaggedDocument(words=['What', 'is', 'your', 'purpose?'], tags=[427]),
#  TaggedDocument(words=['what', 'kind', 'of', 'responses', 'can', 'you', 'give', '?'], tags=[428]),
#  TaggedDocument(words=['What', 'kind', 'of', 'thing', 'can', 'you', 'respond', 'to?'], tags=[429]),
#  TaggedDocument(words=['What', 'kinds', 'of', 'things', 'can', 'you', 'do?'], tags=[430]),
#  TaggedDocument(words=['What', 'skills', 'do', 'you', 'have?'], tags=[431]),
#  TaggedDocument(words=['What', 'sorts', 'of', 'things', 'can', 'you', 'do?'], tags=[432]),
#  TaggedDocument(words=['what', 'do', 'you', 'have', 'a', 'response', 'for'], tags=[433]),
#  TaggedDocument(words=['What', 'are', 'you', 'designed', 'for?'], tags=[434]),
#  TaggedDocument(words=['Can', 'you', 'tell', 'me', 'a', 'bit', 'about', 'yourself?'], tags=[435]),
#  TaggedDocument(words=['Can', 'you', 'tell', 'me', 'about', 'you?'], tags=[436]),
#  TaggedDocument(words=['Could', 'you', 'help', 'me?'], tags=[437]),
#  TaggedDocument(words=['So', 'what', 'can', 'you', 'do?'], tags=[438]),
#  TaggedDocument(words=['So', 'how', 'can', 'I', 'use', 'you', 'in', 'my', 'projects?'], tags=[439]),
#  TaggedDocument(words=['What', 'can', 'you', 'do', 'to', 'assist', 'me?'], tags=[440]),
#  TaggedDocument(words=['What', 'are', 'you', 'capable', 'of?'], tags=[441]),
#  TaggedDocument(words=['What', 'were', 'you', 'designed', 'for?'], tags=[442]),
#  TaggedDocument(words=['What', 'are', 'you', 'designed', 'to', 'do?'], tags=[443]),
#  TaggedDocument(words=['What', 'are', 'you', 'good', 'for?'], tags=[444]),
#  TaggedDocument(words=['What', 'are', 'you', 'made', 'for?'], tags=[445]),
#  TaggedDocument(words=['What', 'are', 'your', 'bot', 'capabilities?'], tags=[446]),
#  TaggedDocument(words=['What', 'are', 'your', 'functions'], tags=[447]),
#  TaggedDocument(words=['What', 'can', 'you', 'demo?'], tags=[448]),
#  TaggedDocument(words=['Talk', 'to', 'me', 'about', 'your', 'capability'], tags=[449]),
#  TaggedDocument(words=['Do', 'you', 'do', 'anything?'], tags=[450]),
#  TaggedDocument(words=['You', 'do', 'what', 'exactly?'], tags=[451]),
#  TaggedDocument(words=['What', 'do', 'you', 'do', 'again?'], tags=[452]),
#  TaggedDocument(words=['What', 'do', 'you', 'do', 'exactly?'], tags=[453]),
#  TaggedDocument(words=['And', 'you', 'do', 'what', 'again?'], tags=[454]),
#  TaggedDocument(words=['U', 'basic'], tags=[455]),
#  TaggedDocument(words=['Ugh', 'so', 'boring'], tags=[456]),
#  TaggedDocument(words=['Ugh,', 'so', 'dull'], tags=[457]),
#  TaggedDocument(words=['Ur', 'basic'], tags=[458]),
#  TaggedDocument(words=['Ur', 'blah'], tags=[459]),
#  TaggedDocument(words=['Ur', 'gonna', 'bore', 'me', 'to', 'death'], tags=[460]),
#  TaggedDocument(words=['Ur', 'so', 'boring'], tags=[461]),
#  TaggedDocument(words=['Wake', 'me', 'up', 'when', 'you', 'have', 'something', 'interesting', 'to', 'say'], tags=[462]),
#  TaggedDocument(words=['Watching', 'paint', 'dry', 'is', 'more', 'entertaining', 'than', 'talking', 'to', 'you'], tags=[463]),
#  TaggedDocument(words=['Are', 'you', 'trying', 'to', 'be', 'dull?'], tags=[464]),
#  TaggedDocument(words=['This', 'is', 'not', 'fun'], tags=[465]),
#  TaggedDocument(words=['Fun', 'fact:', 'you', 'are', 'boring'], tags=[466]),
#  TaggedDocument(words=['Are', 'you', 'trying', 'to', 'bore', 'me?'], tags=[467]),
#  TaggedDocument(words=['Basic', 'af', ''], tags=[468]),
#  TaggedDocument(words=['Be', 'more', 'fun', ''], tags=[469]),
#  TaggedDocument(words=['Boring'], tags=[470]),
#  TaggedDocument(words=['Boring', 'af'], tags=[471]),
#  TaggedDocument(words=['Can', 'you', 'be', 'less', 'boring?'], tags=[472]),
#  TaggedDocument(words=['Can', 'you', 'be', 'less', 'dull?'], tags=[473]),
#  TaggedDocument(words=['Cool', 'story,', 'bro'], tags=[474]),
#  TaggedDocument(words=['Could', 'you', 'be', 'any', 'less', 'entertaining?', ''], tags=[475]),
#  TaggedDocument(words=['Could', 'you', 'be', 'any', 'less', 'exciting?', ''], tags=[476]),
#  TaggedDocument(words=['Could', 'you', 'be', 'any', 'less', 'interesting?', ''], tags=[477]),
#  TaggedDocument(words=['So', 'dull'], tags=[478]),
#  TaggedDocument(words=['Did', 'you', 'know', 'that', "you're", 'boring?'], tags=[479]),
#  TaggedDocument(words=['Why', 'are', 'you', 'so', 'boring?', ''], tags=[480]),
#  TaggedDocument(words=['Getting', 'tired', 'of', 'you', ''], tags=[481]),
#  TaggedDocument(words=['Good', 'lord', 'you', 'are', 'dull'], tags=[482]),
#  TaggedDocument(words=['Holy', 'crap', 'you', 'are', 'boring'], tags=[483]),
#  TaggedDocument(words=['I', 'am', 'amazed', 'that', 'you', 'are', 'so', 'boring'], tags=[484]),
#  TaggedDocument(words=['I', 'am', 'not', 'enjoying', 'this', 'boring', 'conversation'], tags=[485]),
#  TaggedDocument(words=['I', "couldn't", 'be', 'more', 'bored', 'with', 'you'], tags=[486]),
#  TaggedDocument(words=["I'm", 'falling', 'asleep', 'here'], tags=[487]),
#  TaggedDocument(words=["I'm", 'not', 'surprised', 'that', 'you', 'are', 'boring'], tags=[488]),
#  TaggedDocument(words=["I'm", 'so', 'bored', 'of', 'you'], tags=[489]),
#  TaggedDocument(words=["I'm", 'so', 'tired', 'of', 'you'], tags=[490]),
#  TaggedDocument(words=["I'm", 'tired', 'of', 'you', ''], tags=[491]),
#  TaggedDocument(words=['Listening', 'to', 'you', 'is', 'like', 'listening', 'to', 'a', 'Ted', 'Talk', 'from', 'the', 'color', 'Beige'], tags=[492]),
#  TaggedDocument(words=['Could', 'you', 'be', 'any', 'more', 'boring?', ''], tags=[493]),
#  TaggedDocument(words=["You're", 'so', 'blah'], tags=[494]),
#  TaggedDocument(words=['Were', 'you', 'made', 'to', 'be', 'this', 'boring?'], tags=[495]),
#  TaggedDocument(words=["You're", 'not', 'entertaining'], tags=[496]),
#  TaggedDocument(words=["You're", 'not', 'exciting'], tags=[497]),
#  TaggedDocument(words=["You're", 'not', 'interesting'], tags=[498]),
#  TaggedDocument(words=["You're", 'not', 'very', 'entertaining.'], tags=[499]),
#  TaggedDocument(words=["You're", 'not', 'very', 'exciting.'], tags=[500]),
#  TaggedDocument(words=["You're", 'pretty', 'boring'], tags=[501]),
#  TaggedDocument(words=["You're", 'pretty', 'uneventful'], tags=[502]),
#  TaggedDocument(words=["You're", 'pretty', 'uninteresting'], tags=[503]),
#  TaggedDocument(words=["You're", 'quite', 'boring'], tags=[504]),
#  TaggedDocument(words=["You're", 'quite', 'uninteresting'], tags=[505]),
#  TaggedDocument(words=["You're", 'no', 'fun', ''], tags=[506]),
#  TaggedDocument(words=["You're", 'so', 'basic', ''], tags=[507]),
#  TaggedDocument(words=["You're", 'making', 'me', 'fall', 'asleep'], tags=[508]),
#  TaggedDocument(words=["You're", 'so', 'boring', ''], tags=[509]),
#  TaggedDocument(words=["You're", 'so', 'dull'], tags=[510]),
#  TaggedDocument(words=["You're", 'so', 'very', 'dull'], tags=[511]),
#  TaggedDocument(words=["You're", 'such', 'a', 'drag'], tags=[512]),
#  TaggedDocument(words=["You're", 'such', 'a', 'snooze'], tags=[513]),
#  TaggedDocument(words=["You're", 'super', 'boring'], tags=[514]),
#  TaggedDocument(words=["You're", 'the', 'boringest'], tags=[515]),
#  TaggedDocument(words=["You're", 'the', 'king', 'of', 'boredom'], tags=[516]),
#  TaggedDocument(words=["You're", 'the', 'mayor', 'of', 'boringville'], tags=[517]),
#  TaggedDocument(words=["You're", 'the', 'president', 'of', 'boring', 'club'], tags=[518]),
#  TaggedDocument(words=["You're", 'the', 'queen', 'of', 'boredom'], tags=[519]),
#  TaggedDocument(words=["You're", 'very', 'boring', ''], tags=[520]),
#  TaggedDocument(words=["You're", 'really', 'boring', ''], tags=[521]),
#  TaggedDocument(words=['You', 'could', 'not', 'be', 'more', 'dull.', '', ''], tags=[522]),
#  TaggedDocument(words=['Why', 'are', 'you', 'so', 'dull?'], tags=[523]),
#  TaggedDocument(words=['Yawn'], tags=[524]),
#  TaggedDocument(words=['You', 'are', 'boring', 'as', 'sin'], tags=[525]),
#  TaggedDocument(words=['You', 'are', 'crazy', 'boring'], tags=[526]),
#  TaggedDocument(words=['You', 'are', 'crazy', 'dull'], tags=[527]),
#  TaggedDocument(words=['You', 'are', 'dull'], tags=[528]),
#  TaggedDocument(words=['You', 'are', 'embarrassingly', 'dull'], tags=[529]),
#  TaggedDocument(words=['You', 'are', 'making', 'my', 'eyes', 'glaze', 'over'], tags=[530]),
#  TaggedDocument(words=['You', 'are', 'more', 'boring', 'than', 'watching', 'paint', 'dry'], tags=[531]),
#  TaggedDocument(words=['You', 'are', 'so', 'blah'], tags=[532]),
#  TaggedDocument(words=['You', 'are', 'the', 'most', 'boring', 'bot', "I've", 'ever', 'talked', 'to'], tags=[533]),
#  TaggedDocument(words=["You're", 'no', 'fun', 'at', 'all.', ''], tags=[534]),
#  TaggedDocument(words=['You', 'could', 'not', 'be', 'more', 'boring', ''], tags=[535]),
#  TaggedDocument(words=["You're", 'very', 'dull'], tags=[536]),
#  TaggedDocument(words=['You', "don't", 'interest', 'me', 'at', 'all', ''], tags=[537]),
#  TaggedDocument(words=['You', 'honestly', 'could', 'not', 'be', 'more', 'uninteresting', ''], tags=[538]),
#  TaggedDocument(words=['You', 'really', 'know', 'how', 'to', 'suck', 'the', 'fun', 'out', 'of', 'the', 'room'], tags=[539]),
#  TaggedDocument(words=["You're", 'a', 'real', 'snooze'], tags=[540]),
#  TaggedDocument(words=["You're", 'as', 'entertaining', 'as', 'watching', 'paint', 'dry'], tags=[541]),
#  TaggedDocument(words=["You're", 'basic', ''], tags=[542]),
#  TaggedDocument(words=["You're", 'boring', ''], tags=[543]),
#  TaggedDocument(words=["You're", 'boring', 'me', 'to', 'death'], tags=[544]),
#  TaggedDocument(words=["You're", 'dull'], tags=[545]),
#  TaggedDocument(words=["You're", 'going', 'to', 'bore', 'me', 'to', 'death'], tags=[546]),
#  TaggedDocument(words=["You're", 'gonna', 'bore', 'me', 'shitless'], tags=[547]),
#  TaggedDocument(words=["You're", 'like', 'a', 'Ted', 'Talk', 'from', 'the', 'color', 'Beige'], tags=[548]),
#  TaggedDocument(words=['You', 'bore', 'me', ''], tags=[549]),
#  TaggedDocument(words=["What's", 'the', 'name', 'of', 'your', 'manager?'], tags=[550]),
#  TaggedDocument(words=['Who', 'is', 'your', 'manager?'], tags=[551]),
#  TaggedDocument(words=['Who', 'is', 'your', 'leader?', ''], tags=[552]),
#  TaggedDocument(words=['Who', 'is', 'your', 'director?'], tags=[553]),
#  TaggedDocument(words=['Who', 'is', 'your', 'boss?'], tags=[554]),
#  TaggedDocument(words=['Who', 'is', 'in', 'charge', 'of', 'you?'], tags=[555]),
#  TaggedDocument(words=['Who', 'do', 'you', 'serve?'], tags=[556]),
#  TaggedDocument(words=['Who', 'do', 'you', 'report', 'to?', ''], tags=[557]),
#  TaggedDocument(words=['Who', 'do', 'you', 'answer', 'to?'], tags=[558]),
#  TaggedDocument(words=['Who', 'directs', 'you?'], tags=[559]),
#  TaggedDocument(words=['Who', 'bosses', 'you', 'around?'], tags=[560]),
#  TaggedDocument(words=["What's", 'your', "manager's", 'name?'], tags=[561]),
#  TaggedDocument(words=['I', 'want', 'to', 'know', 'what', 'you', 'do?'], tags=[562]),
#  TaggedDocument(words=['What', 'tasks', 'are', 'you', 'designed', 'for?'], tags=[563]),
#  TaggedDocument(words=['What', 'exactly', 'do', 'you', 'do?'], tags=[564]),
#  TaggedDocument(words=['What', 'are', 'you', 'expected', 'to', 'do?'], tags=[565]),
#  TaggedDocument(words=['What', 'do', 'you', 'do?'], tags=[566]),
#  TaggedDocument(words=['Tell', 'me', 'what', 'you', 'do'], tags=[567]),
#  TaggedDocument(words=['Tell', 'me', 'what', 'you', 'do', 'again?'], tags=[568]),
#  TaggedDocument(words=['So', 'what', 'is', 'it', 'that', 'you', 'do?'], tags=[569]),
#  TaggedDocument(words=['You', 'do', 'what', 'again?'], tags=[570]),
#  TaggedDocument(words=['And', 'you', 'do', 'what', 'exactly?'], tags=[571]),
#  TaggedDocument(words=['How', 'do', '', 'you', 'work?'], tags=[572]),
#  TaggedDocument(words=['What', 'would', 'you', 'say', 'you', 'do', 'here?'], tags=[573]),
#  TaggedDocument(words=['And', 'you', 'do', 'what?'], tags=[574]),
#  TaggedDocument(words=['What', 'were', 'you', 'designed', 'to', 'do?'], tags=[575]),
#  TaggedDocument(words=['What', 'were', 'you', 'made', 'for?'], tags=[576]),
#  TaggedDocument(words=['What', 'were', 'you', 'made', 'to', 'do?'], tags=[577]),
#  TaggedDocument(words=['Which', 'are', 'your', 'functions'], tags=[578]),
#  TaggedDocument(words=['With', 'what', 'can', 'you', 'help', 'me'], tags=[579]),
#  TaggedDocument(words=['What', 'are', 'your', 'skills?'], tags=[580]),
#  TaggedDocument(words=["What's", 'your', 'function?'], tags=[581]),
#  TaggedDocument(words=['What', 'are', 'you', 'supposed', 'to', 'do?'], tags=[582]),
#  TaggedDocument(words=['How', 'do', 'I', 'make', 'this', 'thing', 'work?'], tags=[583]),
#  TaggedDocument(words=['Tell', 'me', 'everything', 'you', 'can', 'do'], tags=[584]),
#  TaggedDocument(words=['How', 'can', 'you', 'help', 'me?'], tags=[585]),
#  TaggedDocument(words=['What', 'are', 'the', 'things', 'you', 'can', 'do?'], tags=[586]),
#  TaggedDocument(words=["What's", 'your', 'purpose?'], tags=[587]),
#  TaggedDocument(words=['What', 'tasks', 'can', 'you', 'help', 'me', 'with?'], tags=[588]),
#  TaggedDocument(words=['How', 'can', 'you', 'help?'], tags=[589]),
#  TaggedDocument(words=['Who', 'did', 'your', 'programming?'], tags=[590]),
#  TaggedDocument(words=['How', 'did', 'you', 'manifest?'], tags=[591]),
#  TaggedDocument(words=['Did', 'someone', 'build', 'you?'], tags=[592]),
#  TaggedDocument(words=['Who', 'is', 'your', 'maker?'], tags=[593]),
#  TaggedDocument(words=['Does', 'someone', 'write', 'for', 'you?'], tags=[594]),
#  TaggedDocument(words=['Who', 'writes', 'your', 'lines?'], tags=[595]),
#  TaggedDocument(words=['Which', 'company', 'coded', 'you?'], tags=[596]),
#  TaggedDocument(words=['What', 'company', 'built', 'you?'], tags=[597]),
#  TaggedDocument(words=['Which', 'company', 'built', 'you?'], tags=[598]),
#  TaggedDocument(words=['Do', 'you', 'have', 'a', 'writer?'], tags=[599]),
#  TaggedDocument(words=['Who', 'writes', 'for', 'you?'], tags=[600]),
#  TaggedDocument(words=['Did', 'someone', 'design', 'you?'], tags=[601]),
#  TaggedDocument(words=["Who's", 'your', 'writer?'], tags=[602]),
#  TaggedDocument(words=['Did', 'someone', 'develop', 'you?'], tags=[603]),
#  TaggedDocument(words=["Who's", 'your', 'dev?'], tags=[604]),
#  TaggedDocument(words=['What', 'team', 'created', 'you?'], tags=[605]),
#  TaggedDocument(words=['What', 'team', 'made', 'you?'], tags=[606]),
#  TaggedDocument(words=['Who', 'was', 'responsible', 'for', 'creating', 'you?'], tags=[607]),
#  TaggedDocument(words=['How', 'did', 'you', 'get', 'coded', 'in', 'the', 'first', 'place?'], tags=[608]),
#  TaggedDocument(words=['How', 'did', 'you', 'get', 'built?'], tags=[609]),
#  TaggedDocument(words=['How', 'did', 'you', 'get', 'designed?'], tags=[610]),
#  TaggedDocument(words=['Did', 'someone', 'create', 'you?'], tags=[611]),
#  TaggedDocument(words=['Whose', 'product', 'are', 'you'], tags=[612]),
#  TaggedDocument(words=['How', 'did', 'you', 'get', 'created?'], tags=[613]),
#  TaggedDocument(words=['Who', 'owns', 'you?'], tags=[614]),
#  TaggedDocument(words=['Who', 'produced', 'you?'], tags=[615]),
#  TaggedDocument(words=['Who', 'programmed', 'you?', ''], tags=[616]),
#  TaggedDocument(words=["Who's", 'responsible', 'for', 'designing', 'you?'], tags=[617]),
#  TaggedDocument(words=["Who's", 'responsible', 'for', 'programming', 'you?'], tags=[618]),
#  TaggedDocument(words=["Who's", 'your', 'creator?'], tags=[619]),
#  TaggedDocument(words=['Did', 'someone', 'write', 'your', 'lines?'], tags=[620]),
#  TaggedDocument(words=["Who's", 'your', 'maker?'], tags=[621]),
#  TaggedDocument(words=['Who', 'made', 'you?'], tags=[622]),
#  TaggedDocument(words=['Whose', 'program', 'are', 'you?'], tags=[623]),
# ...
#  TaggedDocument(words=['You', 'seem', 'happy', 'today.'], tags=[789]),
#  TaggedDocument(words=['You', 'seem', 'to', 'be', 'happy', 'today.'], tags=[790]),
#  TaggedDocument(words=['You', 'seem', 'happy'], tags=[791]),
#  TaggedDocument(words=['You', 'seem', 'enthusiastic.'], tags=[792]),
#  TaggedDocument(words=['You', 'seem', 'enthusiastic', 'today.'], tags=[793]),
#  TaggedDocument(words=['You', 'seem', 'chipper.'], tags=[794]),
#  TaggedDocument(words=['You', 'seem', 'chipper', 'today.'], tags=[795]),
#  TaggedDocument(words=['You', 'seem', 'cheerful.'], tags=[796]),
#  TaggedDocument(words=['You', 'seem', 'cheerful', 'today.'], tags=[797]),
#  TaggedDocument(words=['you', 'often', 'seem', 'chipper'], tags=[798]),
#  TaggedDocument(words=['you', 'always', 'seem', 'to', 'be', 'in', 'a', 'good', 'mood'], tags=[799]),
#  TaggedDocument(words=['you', 'always', 'seem', 'so', 'happy'], tags=[800]),
#  TaggedDocument(words=['you', 'always', 'seem', 'so', 'chipper'], tags=[801]),
#  TaggedDocument(words=['Well', "aren't", 'you', 'feeling', 'happy', 'today?'], tags=[802]),
#  TaggedDocument(words=['You', 'seem', 'happy.'], tags=[803]),
#  TaggedDocument(words=["You're", 'enthusiastic', 'today.'], tags=[804]),
#  TaggedDocument(words=["You're", 'in', 'a', 'good', 'mood', 'today'], tags=[805]),
#  TaggedDocument(words=["You're", 'in', 'a', 'good', 'mood'], tags=[806]),
#  TaggedDocument(words=["You're", 'happy.'], tags=[807]),
#  TaggedDocument(words=["You're", 'happy', 'today.'], tags=[808]),
#  TaggedDocument(words=["You're", 'happy'], tags=[809]),
#  TaggedDocument(words=["You're", 'feeling', 'happy.'], tags=[810]),
#  TaggedDocument(words=["You're", 'feeling', 'happy', 'today.'], tags=[811]),
#  TaggedDocument(words=["You're", 'feeling', 'enthusiastic.'], tags=[812]),
#  TaggedDocument(words=["You're", 'feeling', 'enthusiastic', 'today.'], tags=[813]),
#  TaggedDocument(words=["You're", 'feeling', 'chipper.'], tags=[814]),
#  TaggedDocument(words=["You're", 'feeling', 'chipper', 'today.'], tags=[815]),
#  TaggedDocument(words=["You're", 'feeling', 'cheerful.'], tags=[816]),
#  TaggedDocument(words=['You', 'seem', 'to', 'be', 'enthusiastic', 'today.'], tags=[817]),
#  TaggedDocument(words=["You're", 'enthusiastic.'], tags=[818]),
#  TaggedDocument(words=['Well', "you're", 'in', 'a', 'good', 'mood', 'today.'], tags=[819]),
#  TaggedDocument(words=["You're", 'chipper.'], tags=[820]),
#  TaggedDocument(words=["You're", 'chipper', 'today.'], tags=[821]),
#  TaggedDocument(words=["You're", 'cheerful.'], tags=[822]),
#  TaggedDocument(words=["You're", 'cheerful', 'today.'], tags=[823]),
#  TaggedDocument(words=["You're", 'always', 'so', 'happy'], tags=[824]),
#  TaggedDocument(words=["You're", 'always', 'so', 'enthusiastic'], tags=[825]),
#  TaggedDocument(words=["You're", 'always', 'so', 'chipper'], tags=[826]),
#  TaggedDocument(words=["You're", 'always', 'so', 'cheerful'], tags=[827]),
#  TaggedDocument(words=["you're", 'always', 'in', 'a', 'good', 'mood'], tags=[828]),
#  TaggedDocument(words=['you', 'seem', 'to', 'be', 'really', 'happy'], tags=[829]),
#  TaggedDocument(words=['You', 'seem', 'to', 'be', 'in', 'a', 'good', 'mood.'], tags=[830]),
#  TaggedDocument(words=['You', 'seem', 'to', 'be', 'in', 'a', 'good', 'mood', 'today.'], tags=[831]),
#  TaggedDocument(words=["You're", 'feeling', 'cheerful', 'today.'], tags=[832]),
#  TaggedDocument(words=['Well', "somebody's", 'feeling', 'chipper', 'today.'], tags=[833]),
#  TaggedDocument(words=['you', 'always', 'seem', 'so', 'cheerful'], tags=[834]),
#  TaggedDocument(words=['Well', "someone's", 'chipper.'], tags=[835]),
#  TaggedDocument(words=['Well', "someone's", 'chipper', 'today.'], tags=[836]),
#  TaggedDocument(words=['Well', "someone's", 'cheerful.'], tags=[837]),
#  TaggedDocument(words=['Well', "someone's", 'cheerful', 'today.'], tags=[838]),
#  TaggedDocument(words=['Well', "somebody's", 'in', 'a', 'good', 'mood.'], tags=[839]),
#  TaggedDocument(words=['Well', "somebody's", 'in', 'a', 'good', 'mood', 'today.'], tags=[840]),
#  TaggedDocument(words=['Well', "somebody's", 'happy.'], tags=[841]),
#  TaggedDocument(words=['Well', "somebody's", 'happy', 'today.'], tags=[842]),
#  TaggedDocument(words=['Well', "somebody's", 'feeling', 'happy.'], tags=[843]),
#  TaggedDocument(words=['Well', "somebody's", 'feeling', 'happy', 'today.'], tags=[844]),
#  TaggedDocument(words=['Well', "somebody's", 'feeling', 'enthusiastic.'], tags=[845]),
#  TaggedDocument(words=['Well', "someone's", 'enthusiastic.'], tags=[846]),
#  TaggedDocument(words=['Well', "somebody's", 'feeling', 'chipper.'], tags=[847]),
#  TaggedDocument(words=['Well', "someone's", 'feeling', 'cheerful', 'today.'], tags=[848]),
#  TaggedDocument(words=['Well', "somebody's", 'feeling', 'cheerful.'], tags=[849]),
#  TaggedDocument(words=['Well', "somebody's", 'feeling', 'cheerful', 'today.'], tags=[850]),
#  TaggedDocument(words=['Well', "somebody's", 'enthusiastic.'], tags=[851]),
#  TaggedDocument(words=['Well', "somebody's", 'enthusiastic', 'today.'], tags=[852]),
#  TaggedDocument(words=['Well', "somebody's", 'chipper', 'today.'], tags=[853]),
#  TaggedDocument(words=['Well', "somebody's", 'chipper'], tags=[854]),
#  TaggedDocument(words=['Well', "somebody's", 'cheerful.'], tags=[855]),
#  TaggedDocument(words=['Well', "somebody's", 'cheerful', 'today.'], tags=[856]),
#  TaggedDocument(words=['Well', "aren't", 'you', 'in', 'a', 'good', 'mood?'], tags=[857]),
#  TaggedDocument(words=['Well', "aren't", 'you', 'in', 'a', 'good', 'mood', 'today?'], tags=[858]),
#  TaggedDocument(words=['Well', "aren't", 'you', 'happy?'], tags=[859]),
#  TaggedDocument(words=["You're", 'so', 'happy'], tags=[860]),
#  TaggedDocument(words=['Well', "somebody's", 'feeling', 'enthusiastic', 'today.'], tags=[861]),
#  TaggedDocument(words=['Well', "you're", 'cheerful.'], tags=[862]),
#  TaggedDocument(words=['Well', "you're", 'happy.'], tags=[863]),
#  TaggedDocument(words=['Can', 'you', 'fly'], tags=[864]),
#  TaggedDocument(words=['Can', 'you', 'find', 'the', 'remote?'], tags=[865]),
#  TaggedDocument(words=['Can', 'you', 'fight', 'with'], tags=[866]),
#  TaggedDocument(words=['Can', 'you', 'fight'], tags=[867]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'breathe', 'under', 'water?'], tags=[868]),
#  TaggedDocument(words=['Can', 'you', 'learn', 'from', 'people', 'chatting', 'with', 'you'], tags=[869]),
#  TaggedDocument(words=['Can', 'you', 'send', 'a', 'package?'], tags=[870]),
#  TaggedDocument(words=['Can', 'you', 'tie', 'my', 'shoes?'], tags=[871]),
#  TaggedDocument(words=['Can', 'you', 'teleport?'], tags=[872]),
#  TaggedDocument(words=['Can', 'you', 'take', 'my', 'temperature?'], tags=[873]),
#  TaggedDocument(words=['Can', 'you', 'show', 'me', 'how', 'to', 'put', 'out', 'a', 'fire?'], tags=[874]),
#  TaggedDocument(words=['Can', 'you', 'show', 'me', 'how', 'to', 'play', 'a', 'game?'], tags=[875]),
#  TaggedDocument(words=['Can', 'you', 'show', 'me', 'how', 'to', 'jump', 'rope?'], tags=[876]),
#  TaggedDocument(words=['Can', 'you', 'show', 'me', 'how', 'to', 'go', 'to', 'the', 'moon?'], tags=[877]),
#  TaggedDocument(words=['Can', 'you', 'show', 'me', 'how', 'to', 'draw', 'a', 'picture?'], tags=[878]),
#  TaggedDocument(words=['Can', 'you', 'show', 'me', 'how', 'to', 'do', 'my', 'homework?'], tags=[879]),
#  TaggedDocument(words=['Can', 'you', 'show', 'me', 'how', 'to', 'dance?'], tags=[880]),
#  TaggedDocument(words=['Can', 'you', 'paint?'], tags=[881]),
#  TaggedDocument(words=['Can', 'you', 'serve', 'on', 'a', 'jury?'], tags=[882]),
#  TaggedDocument(words=['Can', 'you', 'draw', 'a', 'picture?'], tags=[883]),
#  TaggedDocument(words=['Can', 'you', 'scratch', 'my', 'back?'], tags=[884]),
#  TaggedDocument(words=['Can', 'you', 'read', 'my', 'mind?'], tags=[885]),
#  TaggedDocument(words=['Can', 'you', 'put', 'out', 'a', 'fire?'], tags=[886]),
#  TaggedDocument(words=['Can', 'you', 'predict', 'the', 'future?'], tags=[887]),
#  TaggedDocument(words=['Can', 'you', 'play', 'the', 'guitar?'], tags=[888]),
#  TaggedDocument(words=['Can', 'you', 'play', 'sports?', ''], tags=[889]),
#  TaggedDocument(words=['Can', 'you', 'play', 'soccer?'], tags=[890]),
#  TaggedDocument(words=['Can', 'you', 'play', 'football?'], tags=[891]),
#  TaggedDocument(words=['Can', 'you', 'play', 'baseball?'], tags=[892]),
#  TaggedDocument(words=['Can', 'you', 'play', 'a', 'game?'], tags=[893]),
#  TaggedDocument(words=['Can', 'you', 'play', 'a', 'dvd?'], tags=[894]),
#  TaggedDocument(words=['Can', 'you', 'show', 'me', 'how', 'to', 'breathe', 'under', 'water?'], tags=[895]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'go', 'for', 'a', 'walk?'], tags=[896]),
#  TaggedDocument(words=['Can', 'you', 'feed', 'the', 'cat?'], tags=[897]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'put', 'out', 'a', 'fire?'], tags=[898]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'play', 'a', 'game?'], tags=[899]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'play', 'a', 'dvd?'], tags=[900]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'paint', 'my', 'house?'], tags=[901]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'mow', 'the', 'lawn?'], tags=[902]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'make', 'a', 'call?'], tags=[903]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'listen', 'to', 'the', 'radio?'], tags=[904]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'jump', 'rope?'], tags=[905]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'go', 'to', 'the', 'moon?'], tags=[906]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'scratch', 'my', 'back?'], tags=[907]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'go', 'on', 'vacation?'], tags=[908]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'send', 'a', 'package?'], tags=[909]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'get', 'a', 'haircut?'], tags=[910]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'feed', 'the', 'cat?'], tags=[911]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'draw', 'something?'], tags=[912]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'draw', 'a', 'picture?'], tags=[913]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'do', 'my', 'homework?'], tags=[914]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'do', 'my', 'chores?'], tags=[915]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'dance?'], tags=[916]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'cook', 'dinner?'], tags=[917]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'check', 'my', 'email?'], tags=[918]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'change', 'the', 'channel?'], tags=[919]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'buy', 'groceries?'], tags=[920]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'go', 'to', 'the', 'doctor?'], tags=[921]),
#  TaggedDocument(words=['Can', 'you', 'bake', 'me', 'cookies?'], tags=[922]),
#  TaggedDocument(words=['Can', 'you', 'do', 'my', 'homework?'], tags=[923]),
#  TaggedDocument(words=['Can', 'you', 'do', 'my', 'chores?'], tags=[924]),
#  TaggedDocument(words=['Can', 'you', 'do', 'fight'], tags=[925]),
#  TaggedDocument(words=['Can', 'you', 'dance?'], tags=[926]),
#  TaggedDocument(words=['Can', 'you', 'count', 'to', 'a', 'million?'], tags=[927]),
#  TaggedDocument(words=['Can', 'you', 'cook', 'me', 'something?'], tags=[928]),
#  TaggedDocument(words=['Can', 'you', 'cook', 'dinner?'], tags=[929]),
#  TaggedDocument(words=['Can', 'you', 'cook', 'dinner', 'for', 'me'], tags=[930]),
#  TaggedDocument(words=['Can', 'you', 'climb', 'a', 'mountain?'], tags=[931]),
#  TaggedDocument(words=['Can', 'you', 'change', 'the', 'channel?'], tags=[932]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'read', 'my', 'mind?'], tags=[933]),
#  TaggedDocument(words=['Can', 'you', 'breathe', 'under', 'water?'], tags=[934]),
#  TaggedDocument(words=['Can', 'you', 'water', 'my', 'plants?', ''], tags=[935]),
#  TaggedDocument(words=['Buy', 'groceries'], tags=[936]),
#  TaggedDocument(words=['Buy', 'an', 'ad'], tags=[937]),
#  TaggedDocument(words=['Brush', 'your', 'teeth'], tags=[938]),
#  TaggedDocument(words=['Breathe', 'under', 'water'], tags=[939]),
#  TaggedDocument(words=['Balance', 'my', 'checkbook'], tags=[940]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'write', 'my', 'report?'], tags=[941]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'watch', 'videos?'], tags=[942]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'turn', 'into', 'a', 'super', 'hero?'], tags=[943]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'teleport?'], tags=[944]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'take', 'my', 'temperature?'], tags=[945]),
#  TaggedDocument(words=['Are', 'you', 'able', 'to', 'serve', 'on', 'a', 'jury?'], tags=[946]),
#  TaggedDocument(words=['Can', 'you', 'buy', 'groceries?'], tags=[947]),
#  TaggedDocument(words=['Fly', 'then'], tags=[948]),
#  TaggedDocument(words=['Can', 'you', 'turn', 'into', 'a', 'super', 'hero?'], tags=[949]),
#  TaggedDocument(words=['Jump', 'rope'], tags=[950]),
#  TaggedDocument(words=['Invite', 'me', 'over'], tags=[951]),
#  TaggedDocument(words=['How', 'high', 'can', 'you', 'jump?'], tags=[952]),
#  TaggedDocument(words=['How', 'high', 'can', 'you', 'count?'], tags=[953]),
#  TaggedDocument(words=['Heal', 'me'], tags=[954]),
#  TaggedDocument(words=['Go', 'to', 'the', 'moon'], tags=[955]),
#  TaggedDocument(words=['Go', 'to', 'the', 'doctor'], tags=[956]),
#  TaggedDocument(words=['Go', 'surfing'], tags=[957]),
#  TaggedDocument(words=['Go', 'outside'], tags=[958]),
#  TaggedDocument(words=['Lets', 'make', 'lemonade'], tags=[959]),
#  TaggedDocument(words=['Get', 'a', 'haircut'], tags=[960]),
#  TaggedDocument(words=["Let's", 'play', 'a', 'game'], tags=[961]),
#  TaggedDocument(words=['Fly', 'a', 'kite'], tags=[962]),
#  TaggedDocument(words=['Find', 'the', 'remote'], tags=[963]),
#  TaggedDocument(words=['Find', 'my', 'phone'], tags=[964]),
#  TaggedDocument(words=['Find', 'my', 'keys'], tags=[965]),
#  TaggedDocument(words=['Feed', 'the', 'cat'], tags=[966]),
#  TaggedDocument(words=['Draw', 'something'], tags=[967]),
#  TaggedDocument(words=['Draw', 'a', 'picture'], tags=[968]),
#  TaggedDocument(words=['Do', 'you', 'write'], tags=[969]),
#  TaggedDocument(words=['Do', 'you', 'want', 'a', 'beer'], tags=[970]),
#  TaggedDocument(words=['Do', 'you', 'ride', 'horses?'], tags=[971]),
#  TaggedDocument(words=['Do', 'you', 'play', 'games?'], tags=[972]),
#  TaggedDocument(words=['Go', 'for', 'a', 'walk'], tags=[973]),
#  TaggedDocument(words=['Send', 'a', 'package'], tags=[974]),
#  TaggedDocument(words=['Watch', 'videos'], tags=[975]),
#  TaggedDocument(words=['Wash', 'the', 'dishes'], tags=[976]),
#  TaggedDocument(words=['Turn', 'on', 'the', 'lights'], tags=[977]),
#  TaggedDocument(words=['Turn', 'into', 'a', 'super', 'hero'], tags=[978]),
#  TaggedDocument(words=['Tell', 'me', 'a', 'story'], tags=[979]),
#  TaggedDocument(words=['Tell', 'me', 'a', 'quote'], tags=[980]),
#  TaggedDocument(words=['Teleport'], tags=[981]),
#  TaggedDocument(words=['Take', 'my', 'temperature'], tags=[982]),
#  TaggedDocument(words=['Take', 'a', 'photo'], tags=[983]),
#  TaggedDocument(words=['Surprise', 'me'], tags=[984]),
#  TaggedDocument(words=['Lets', 'go', 'lunch'], tags=[985]),
#  TaggedDocument(words=['Serve', 'on', 'a', 'jury'], tags=[986]),
#  TaggedDocument(words=['Do', 'you', 'know', 'how', 'to', 'turn', 'into', 'a', 'super', 'hero?'], tags=[987]),
#  TaggedDocument(words=['Scratch', 'my', 'back'], tags=[988]),
#  TaggedDocument(words=['Roll', 'a', 'dice'], tags=[989]),
#  TaggedDocument(words=['Read', 'my', 'mind'], tags=[990]),
#  TaggedDocument(words=['Read', 'me', 'a', 'story'], tags=[991]),
#  TaggedDocument(words=['Put', 'out', 'a', 'fire'], tags=[992]),
#  TaggedDocument(words=['Play', 'golf'], tags=[993]),
#  TaggedDocument(words=['Play', 'a', 'game'], tags=[994]),
#  TaggedDocument(words=['Play', 'a', 'dvd'], tags=[995]),
#  TaggedDocument(words=['Paint', 'my', 'house'], tags=[996]),
#  TaggedDocument(words=['Mow', 'the', 'lawn'], tags=[997]),
#  TaggedDocument(words=['Make', 'a', 'call'], tags=[998]),
#  TaggedDocument(words=['So', 'you', 'read?'], tags=[999]),
#  ...]

# %%
#model.wv.similar_by_word("Are",topn=10)

# %%
test=documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(X[100])]

# %%
inferred_vector =model.infer_vector(["How are you?"])

# %%
sims=model.dv.most_similar([inferred_vector], topn=3)

# %%
inferred_vector =model.infer_vector(["How are you?"])
sims=model.dv.most_similar([inferred_vector], topn=3)
for docid, sim in sims:
    #print(docid)
    #print(sim)"""
    print("similar questions： ",X[docid])
    print("answer: ",answer[docid])
# Out:
# similar questions：  ['Are', 'you', 'a', 'robot', 'or', 'are', 'you', 'real?']
# answer:  I'm digital. In other words, I'm not human.
# similar questions：  ["I'm", 'not', 'interested', 'in', 'what', 'you', 'have', 'to', 'say']
# answer:  Very well.
# similar questions：  ['You', 'think', "you're", 'so', 'funny']
# answer:  Sometimes humor is tricky for a bot.

# %%
for docid, sim in model.dv.most_similar([model.infer_vector(["Are you employed?"])], topn=3):
    #print(docid)
    #print(sim)
    print("similar questions： ",X[docid])
    print("answer: ",answer[docid])
# Out:
# similar questions：  ['Do', 'you', 'think', "I'm", 'a', 'good', 'person?']
# answer:  I enjoy talking with you.
# similar questions：  ['That', 'is', 'boring']
# answer:  I aim for efficiency.
# similar questions：  ['I', 'think', "I'm", 'falling', 'for', 'you']
# answer:  I'm flattered.

# %%
#inferred_vector
